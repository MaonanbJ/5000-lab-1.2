# %% [raw]
# ---
# title: "Habits"
# author: "John Doe"
# format: revealjs
# bibliography: ../reference.bib
# ---
#
# ## cite
# [@ko2022survey]
#
# ## picture1
# ![picture1](./images/example1.png)
#
# ## picture2
# ![picture2](./images/example2.png)

# %% [markdown]
# ## picture3

# %%
#| echo: true
#| code-fold: true
#| code-summary: "Show the code"

import matplotlib.pyplot as plt
import numpy as np

y = np.random.randn(1000).cumsum()
x = np.arange(len(y))

plt.plot(x, y) 
plt.xlabel('sample') 
plt.ylabel('mean') 
plt.show()
