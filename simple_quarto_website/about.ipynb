# %% [raw]
# ---
# title: "About"
# ---
#
# # first level
# Suspendisse sed elementum lacus, in congue erat. Aenean metus ex, posuere eget varius id,
# rutrum sed felis. Pellentesque laoreet ipsum in orci tincidunt
#
# ## sencond level
# Donec eu tristique velit, in vulputate ligula. Morbi a orci id sem facilisis convallis.
# Donec volutpat lobortis ultrices. Mauris imperdiet tincidunt dignissim.
#
# ### third level
#  Vestibulum ante ipsum primis in faucibus orci luctus et ultrices posuere cubilia curae;
#  Curabitur sem augue, hendrerit et gravida ut, pretium vitae dui.

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.random.randn(1000).cumsum()
x = np.arange(len(y))

plt.plot(x, y) 
plt.xlabel('sample') 
plt.ylabel('mean') 
plt.show()
